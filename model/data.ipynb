# %% [markdown]
# Access Key (experimental) - grtufe45f94725853164fb4cab2772dedb6d61fbb3414817000540c070747bff9cb8

# %%
from gretel_client.navigator_client import Gretel

# We import AIDD column and parameter types using this shorthand for convenience.
import gretel_client.data_designer.params as P
import gretel_client.data_designer.columns as C

# The Gretel object is the SDK's main entry point for interacting with Gretel's API.
gretel = Gretel(api_key="grtufe45f94725853164fb4cab2772dedb6d61fbb3414817000540c070747bff9cb8")
# Out:
# Logged in as alexc10131@gmail.com ✅
# Using project: default-sdk-project-dcf71ffc49babf1
# Project link: https://console.gretel.ai/proj_33aAukCC2qZnzugcXGsaMCxIoBd

# %%
# Initialize a new Data Designer instance using the `data_designer` factory.
designer = gretel.data_designer.new(model_suite="apache-2.0")

# %%
## Use Magic to create a new sampling column.
designer.magic.add_sampling_column("income", "A person's annual income in AUD, between 20000 and 150000")
designer.magic.add_sampling_column("family_size", "Amount of people in a person's family, between 1 and 10")
designer.magic.add_sampling_column("medical_expense", "Amount of money annually a person spends on medical expenses, between 0 and 20000")
designer.magic.add_sampling_column("convicted", "If a peron has been convicted of a crime, 1 for true, 0 for false")
designer.magic.add_sampling_column("homeless", "If a person is homeless, 1 for true, 0 for false")
# Out:
#     <div style="background-color: #FFF3CD;
#                 color: #856404;
#                 padding: 10px;
#                 margin: 10px 0;
#                 border-left: 6px solid #FFE187;
#                 border-radius: 4px;">
#         <p style="margin: 0;">
#             <strong>🧪 Experimental Feature:</strong> Thanks for trying the 🪄 Magic `DataDesigner` interface! This interface is experimental and will likely change in the future. Please let us know your feedback and any issues @ https://github.com/gretelai/gretel-python-client/issues/new.
#
#         </p>
#     </div>
# ╭─ 💬 income ─────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ A person's annual income in AUD, between 20000 and 150000                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# /Users/arona/Documents/GitHub/Visionary-Model/.venv/lib/python3.12/site-packages/rich/live.py:256: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <meta charset="UTF-8">
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# .code .hll { background-color: #3B4252 }
# .code { background: #2E3440; color: #D8DEE9 }
# .code .c { color: #616E87; font-style: italic } /* Comment */
# .code .err { color: #BF616A } /* Error */
# .code .esc { color: #D8DEE9 } /* Escape */
# .code .g { color: #D8DEE9 } /* Generic */
# .code .k { color: #81A1C1; font-weight: bold } /* Keyword */
# .code .l { color: #D8DEE9 } /* Literal */
# .code .n { color: #D8DEE9 } /* Name */
# .code .o { color: #81A1C1; font-weight: bold } /* Operator */
# .code .x { color: #D8DEE9 } /* Other */
# .code .p { color: #ECEFF4 } /* Punctuation */
# .code .ch { color: #616E87; font-style: italic } /* Comment.Hashbang */
# .code .cm { color: #616E87; font-style: italic } /* Comment.Multiline */
# .code .cp { color: #5E81AC; font-style: italic } /* Comment.Preproc */
# .code .cpf { color: #616E87; font-style: italic } /* Comment.PreprocFile */
# .code .c1 { color: #616E87; font-style: italic } /* Comment.Single */
# .code .cs { color: #616E87; font-style: italic } /* Comment.Special */
# .code .gd { color: #BF616A } /* Generic.Deleted */
# .code .ge { color: #D8DEE9; font-style: italic } /* Generic.Emph */
# .code .ges { color: #D8DEE9; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .code .gr { color: #BF616A } /* Generic.Error */
# .code .gh { color: #88C0D0; font-weight: bold } /* Generic.Heading */
# .code .gi { color: #A3BE8C } /* Generic.Inserted */
# .code .go { color: #D8DEE9 } /* Generic.Output */
# .code .gp { color: #616E88; font-weight: bold } /* Generic.Prompt */
# .code .gs { color: #D8DEE9; font-weight: bold } /* Generic.Strong */
# .code .gu { color: #88C0D0; font-weight: bold } /* Generic.Subheading */
# .code .gt { color: #BF616A } /* Generic.Traceback */
# .code .kc { color: #81A1C1; font-weight: bold } /* Keyword.Constant */
# .code .kd { color: #81A1C1; font-weight: bold } /* Keyword.Declaration */
# .code .kn { color: #81A1C1; font-weight: bold } /* Keyword.Namespace */
# .code .kp { color: #81A1C1 } /* Keyword.Pseudo */
# .code .kr { color: #81A1C1; font-weight: bold } /* Keyword.Reserved */
# .code .kt { color: #81A1C1 } /* Keyword.Type */
# .code .ld { color: #D8DEE9 } /* Literal.Date */
# .code .m { color: #B48EAD } /* Literal.Number */
# .code .s { color: #A3BE8C } /* Literal.String */
# .code .na { color: #8FBCBB } /* Name.Attribute */
# .code .nb { color: #81A1C1 } /* Name.Builtin */
# .code .nc { color: #8FBCBB } /* Name.Class */
# .code .no { color: #8FBCBB } /* Name.Constant */
# .code .nd { color: #D08770 } /* Name.Decorator */
# .code .ni { color: #D08770 } /* Name.Entity */
# .code .ne { color: #BF616A } /* Name.Exception */
# .code .nf { color: #88C0D0 } /* Name.Function */
# .code .nl { color: #D8DEE9 } /* Name.Label */
# .code .nn { color: #8FBCBB } /* Name.Namespace */
# .code .nx { color: #D8DEE9 } /* Name.Other */
# .code .py { color: #D8DEE9 } /* Name.Property */
# .code .nt { color: #81A1C1 } /* Name.Tag */
# .code .nv { color: #D8DEE9 } /* Name.Variable */
# .code .ow { color: #81A1C1; font-weight: bold } /* Operator.Word */
# .code .pm { color: #ECEFF4 } /* Punctuation.Marker */
# .code .w { color: #D8DEE9 } /* Text.Whitespace */
# .code .mb { color: #B48EAD } /* Literal.Number.Bin */
# .code .mf { color: #B48EAD } /* Literal.Number.Float */
# .code .mh { color: #B48EAD } /* Literal.Number.Hex */
# .code .mi { color: #B48EAD } /* Literal.Number.Integer */
# .code .mo { color: #B48EAD } /* Literal.Number.Oct */
# .code .sa { color: #A3BE8C } /* Literal.String.Affix */
# .code .sb { color: #A3BE8C } /* Literal.String.Backtick */
# .code .sc { color: #A3BE8C } /* Literal.String.Char */
# .code .dl { color: #A3BE8C } /* Literal.String.Delimiter */
# .code .sd { color: #616E87 } /* Literal.String.Doc */
# .code .s2 { color: #A3BE8C } /* Literal.String.Double */
# .code .se { color: #EBCB8B } /* Literal.String.Escape */
# .code .sh { color: #A3BE8C } /* Literal.String.Heredoc */
# .code .si { color: #A3BE8C } /* Literal.String.Interpol */
# .code .sx { color: #A3BE8C } /* Literal.String.Other */
# .code .sr { color: #EBCB8B } /* Literal.String.Regex */
# .code .s1 { color: #A3BE8C } /* Literal.String.Single */
# .code .ss { color: #A3BE8C } /* Literal.String.Symbol */
# .code .bp { color: #81A1C1 } /* Name.Builtin.Pseudo */
# .code .fm { color: #88C0D0 } /* Name.Function.Magic */
# .code .vc { color: #D8DEE9 } /* Name.Variable.Class */
# .code .vg { color: #D8DEE9 } /* Name.Variable.Global */
# .code .vi { color: #D8DEE9 } /* Name.Variable.Instance */
# .code .vm { color: #D8DEE9 } /* Name.Variable.Magic */
# .code .il { color: #B48EAD } /* Literal.Number.Integer.Long */
#
# .code {
#   padding: 4px;
#   border: 1px solid grey;
#   border-radius: 4px;
#   max-width: 1000px;
#   width: 100%;
#   display: inline-block;
#   box-sizing: border-box;
#   text-align: left;
#   vertical-align: top;
#   line-height: normal;
#   overflow-x: auto;
# }
#
# .code pre {
#   white-space: pre-wrap;       /* CSS 3 */
#   white-space: -moz-pre-wrap;  /* Mozilla, since 1999 */
#   white-space: -pre-wrap;      /* Opera 4-6 */
#   white-space: -o-pre-wrap;    /* Opera 7 */
#   word-wrap: break-word;
#   overflow-wrap: break-word;
#   margin: 0;
# }
# </style>
# <div class="code"><pre><span></span><span class="n">SamplerColumn</span><span class="p">(</span>
#     <span class="n">name</span><span class="o">=</span><span class="s1">&#39;income&#39;</span><span class="p">,</span>
#     <span class="nb">type</span><span class="o">=</span><span class="s1">&#39;uniform&#39;</span><span class="p">,</span>
#     <span class="n">params</span><span class="o">=</span><span class="p">{</span>
#     <span class="s2">&quot;low&quot;</span><span class="p">:</span> <span class="mf">20000.0</span><span class="p">,</span>
#     <span class="s2">&quot;high&quot;</span><span class="p">:</span> <span class="mf">150000.0</span>
# <span class="p">},</span>
#     <span class="n">conditional_params</span><span class="o">=</span><span class="p">{},</span>
#     <span class="n">convert_to</span><span class="o">=</span><span class="kc">None</span>
# <span class="p">)</span>
# </pre></div>
# 🪄 Column income updated in source DataDesigner!
# ╭─ 💬 family_size ────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Amount of people in a person's family, between 1 and 10                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <meta charset="UTF-8">
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# .code .hll { background-color: #3B4252 }
# .code { background: #2E3440; color: #D8DEE9 }
# .code .c { color: #616E87; font-style: italic } /* Comment */
# .code .err { color: #BF616A } /* Error */
# .code .esc { color: #D8DEE9 } /* Escape */
# .code .g { color: #D8DEE9 } /* Generic */
# .code .k { color: #81A1C1; font-weight: bold } /* Keyword */
# .code .l { color: #D8DEE9 } /* Literal */
# .code .n { color: #D8DEE9 } /* Name */
# .code .o { color: #81A1C1; font-weight: bold } /* Operator */
# .code .x { color: #D8DEE9 } /* Other */
# .code .p { color: #ECEFF4 } /* Punctuation */
# .code .ch { color: #616E87; font-style: italic } /* Comment.Hashbang */
# .code .cm { color: #616E87; font-style: italic } /* Comment.Multiline */
# .code .cp { color: #5E81AC; font-style: italic } /* Comment.Preproc */
# .code .cpf { color: #616E87; font-style: italic } /* Comment.PreprocFile */
# .code .c1 { color: #616E87; font-style: italic } /* Comment.Single */
# .code .cs { color: #616E87; font-style: italic } /* Comment.Special */
# .code .gd { color: #BF616A } /* Generic.Deleted */
# .code .ge { color: #D8DEE9; font-style: italic } /* Generic.Emph */
# .code .ges { color: #D8DEE9; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .code .gr { color: #BF616A } /* Generic.Error */
# .code .gh { color: #88C0D0; font-weight: bold } /* Generic.Heading */
# .code .gi { color: #A3BE8C } /* Generic.Inserted */
# .code .go { color: #D8DEE9 } /* Generic.Output */
# .code .gp { color: #616E88; font-weight: bold } /* Generic.Prompt */
# .code .gs { color: #D8DEE9; font-weight: bold } /* Generic.Strong */
# .code .gu { color: #88C0D0; font-weight: bold } /* Generic.Subheading */
# .code .gt { color: #BF616A } /* Generic.Traceback */
# .code .kc { color: #81A1C1; font-weight: bold } /* Keyword.Constant */
# .code .kd { color: #81A1C1; font-weight: bold } /* Keyword.Declaration */
# .code .kn { color: #81A1C1; font-weight: bold } /* Keyword.Namespace */
# .code .kp { color: #81A1C1 } /* Keyword.Pseudo */
# .code .kr { color: #81A1C1; font-weight: bold } /* Keyword.Reserved */
# .code .kt { color: #81A1C1 } /* Keyword.Type */
# .code .ld { color: #D8DEE9 } /* Literal.Date */
# .code .m { color: #B48EAD } /* Literal.Number */
# .code .s { color: #A3BE8C } /* Literal.String */
# .code .na { color: #8FBCBB } /* Name.Attribute */
# .code .nb { color: #81A1C1 } /* Name.Builtin */
# .code .nc { color: #8FBCBB } /* Name.Class */
# .code .no { color: #8FBCBB } /* Name.Constant */
# .code .nd { color: #D08770 } /* Name.Decorator */
# .code .ni { color: #D08770 } /* Name.Entity */
# .code .ne { color: #BF616A } /* Name.Exception */
# .code .nf { color: #88C0D0 } /* Name.Function */
# .code .nl { color: #D8DEE9 } /* Name.Label */
# .code .nn { color: #8FBCBB } /* Name.Namespace */
# .code .nx { color: #D8DEE9 } /* Name.Other */
# .code .py { color: #D8DEE9 } /* Name.Property */
# .code .nt { color: #81A1C1 } /* Name.Tag */
# .code .nv { color: #D8DEE9 } /* Name.Variable */
# .code .ow { color: #81A1C1; font-weight: bold } /* Operator.Word */
# .code .pm { color: #ECEFF4 } /* Punctuation.Marker */
# .code .w { color: #D8DEE9 } /* Text.Whitespace */
# .code .mb { color: #B48EAD } /* Literal.Number.Bin */
# .code .mf { color: #B48EAD } /* Literal.Number.Float */
# .code .mh { color: #B48EAD } /* Literal.Number.Hex */
# .code .mi { color: #B48EAD } /* Literal.Number.Integer */
# .code .mo { color: #B48EAD } /* Literal.Number.Oct */
# .code .sa { color: #A3BE8C } /* Literal.String.Affix */
# .code .sb { color: #A3BE8C } /* Literal.String.Backtick */
# .code .sc { color: #A3BE8C } /* Literal.String.Char */
# .code .dl { color: #A3BE8C } /* Literal.String.Delimiter */
# .code .sd { color: #616E87 } /* Literal.String.Doc */
# .code .s2 { color: #A3BE8C } /* Literal.String.Double */
# .code .se { color: #EBCB8B } /* Literal.String.Escape */
# .code .sh { color: #A3BE8C } /* Literal.String.Heredoc */
# .code .si { color: #A3BE8C } /* Literal.String.Interpol */
# .code .sx { color: #A3BE8C } /* Literal.String.Other */
# .code .sr { color: #EBCB8B } /* Literal.String.Regex */
# .code .s1 { color: #A3BE8C } /* Literal.String.Single */
# .code .ss { color: #A3BE8C } /* Literal.String.Symbol */
# .code .bp { color: #81A1C1 } /* Name.Builtin.Pseudo */
# .code .fm { color: #88C0D0 } /* Name.Function.Magic */
# .code .vc { color: #D8DEE9 } /* Name.Variable.Class */
# .code .vg { color: #D8DEE9 } /* Name.Variable.Global */
# .code .vi { color: #D8DEE9 } /* Name.Variable.Instance */
# .code .vm { color: #D8DEE9 } /* Name.Variable.Magic */
# .code .il { color: #B48EAD } /* Literal.Number.Integer.Long */
#
# .code {
#   padding: 4px;
#   border: 1px solid grey;
#   border-radius: 4px;
#   max-width: 1000px;
#   width: 100%;
#   display: inline-block;
#   box-sizing: border-box;
#   text-align: left;
#   vertical-align: top;
#   line-height: normal;
#   overflow-x: auto;
# }
#
# .code pre {
#   white-space: pre-wrap;       /* CSS 3 */
#   white-space: -moz-pre-wrap;  /* Mozilla, since 1999 */
#   white-space: -pre-wrap;      /* Opera 4-6 */
#   white-space: -o-pre-wrap;    /* Opera 7 */
#   word-wrap: break-word;
#   overflow-wrap: break-word;
#   margin: 0;
# }
# </style>
# <div class="code"><pre><span></span><span class="n">SamplerColumn</span><span class="p">(</span>
#     <span class="n">name</span><span class="o">=</span><span class="s1">&#39;family_size&#39;</span><span class="p">,</span>
#     <span class="nb">type</span><span class="o">=</span><span class="s1">&#39;uniform&#39;</span><span class="p">,</span>
#     <span class="n">params</span><span class="o">=</span><span class="p">{</span>
#     <span class="s2">&quot;low&quot;</span><span class="p">:</span> <span class="mf">1.0</span><span class="p">,</span>
#     <span class="s2">&quot;high&quot;</span><span class="p">:</span> <span class="mf">10.0</span>
# <span class="p">},</span>
#     <span class="n">conditional_params</span><span class="o">=</span><span class="p">{},</span>
#     <span class="n">convert_to</span><span class="o">=</span><span class="kc">None</span>
# <span class="p">)</span>
# </pre></div>
# 🪄 Column family_size updated in source DataDesigner!
# ╭─ 💬 medical_expense ────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Amount of money annually a person spends on medical expenses, between 0 and 20000                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <meta charset="UTF-8">
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# .code .hll { background-color: #3B4252 }
# .code { background: #2E3440; color: #D8DEE9 }
# .code .c { color: #616E87; font-style: italic } /* Comment */
# .code .err { color: #BF616A } /* Error */
# .code .esc { color: #D8DEE9 } /* Escape */
# .code .g { color: #D8DEE9 } /* Generic */
# .code .k { color: #81A1C1; font-weight: bold } /* Keyword */
# .code .l { color: #D8DEE9 } /* Literal */
# .code .n { color: #D8DEE9 } /* Name */
# .code .o { color: #81A1C1; font-weight: bold } /* Operator */
# .code .x { color: #D8DEE9 } /* Other */
# .code .p { color: #ECEFF4 } /* Punctuation */
# .code .ch { color: #616E87; font-style: italic } /* Comment.Hashbang */
# .code .cm { color: #616E87; font-style: italic } /* Comment.Multiline */
# .code .cp { color: #5E81AC; font-style: italic } /* Comment.Preproc */
# .code .cpf { color: #616E87; font-style: italic } /* Comment.PreprocFile */
# .code .c1 { color: #616E87; font-style: italic } /* Comment.Single */
# .code .cs { color: #616E87; font-style: italic } /* Comment.Special */
# .code .gd { color: #BF616A } /* Generic.Deleted */
# .code .ge { color: #D8DEE9; font-style: italic } /* Generic.Emph */
# .code .ges { color: #D8DEE9; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .code .gr { color: #BF616A } /* Generic.Error */
# .code .gh { color: #88C0D0; font-weight: bold } /* Generic.Heading */
# .code .gi { color: #A3BE8C } /* Generic.Inserted */
# .code .go { color: #D8DEE9 } /* Generic.Output */
# .code .gp { color: #616E88; font-weight: bold } /* Generic.Prompt */
# .code .gs { color: #D8DEE9; font-weight: bold } /* Generic.Strong */
# .code .gu { color: #88C0D0; font-weight: bold } /* Generic.Subheading */
# .code .gt { color: #BF616A } /* Generic.Traceback */
# .code .kc { color: #81A1C1; font-weight: bold } /* Keyword.Constant */
# .code .kd { color: #81A1C1; font-weight: bold } /* Keyword.Declaration */
# .code .kn { color: #81A1C1; font-weight: bold } /* Keyword.Namespace */
# .code .kp { color: #81A1C1 } /* Keyword.Pseudo */
# .code .kr { color: #81A1C1; font-weight: bold } /* Keyword.Reserved */
# .code .kt { color: #81A1C1 } /* Keyword.Type */
# .code .ld { color: #D8DEE9 } /* Literal.Date */
# .code .m { color: #B48EAD } /* Literal.Number */
# .code .s { color: #A3BE8C } /* Literal.String */
# .code .na { color: #8FBCBB } /* Name.Attribute */
# .code .nb { color: #81A1C1 } /* Name.Builtin */
# .code .nc { color: #8FBCBB } /* Name.Class */
# .code .no { color: #8FBCBB } /* Name.Constant */
# .code .nd { color: #D08770 } /* Name.Decorator */
# .code .ni { color: #D08770 } /* Name.Entity */
# .code .ne { color: #BF616A } /* Name.Exception */
# .code .nf { color: #88C0D0 } /* Name.Function */
# .code .nl { color: #D8DEE9 } /* Name.Label */
# .code .nn { color: #8FBCBB } /* Name.Namespace */
# .code .nx { color: #D8DEE9 } /* Name.Other */
# .code .py { color: #D8DEE9 } /* Name.Property */
# .code .nt { color: #81A1C1 } /* Name.Tag */
# .code .nv { color: #D8DEE9 } /* Name.Variable */
# .code .ow { color: #81A1C1; font-weight: bold } /* Operator.Word */
# .code .pm { color: #ECEFF4 } /* Punctuation.Marker */
# .code .w { color: #D8DEE9 } /* Text.Whitespace */
# .code .mb { color: #B48EAD } /* Literal.Number.Bin */
# .code .mf { color: #B48EAD } /* Literal.Number.Float */
# .code .mh { color: #B48EAD } /* Literal.Number.Hex */
# .code .mi { color: #B48EAD } /* Literal.Number.Integer */
# .code .mo { color: #B48EAD } /* Literal.Number.Oct */
# .code .sa { color: #A3BE8C } /* Literal.String.Affix */
# .code .sb { color: #A3BE8C } /* Literal.String.Backtick */
# .code .sc { color: #A3BE8C } /* Literal.String.Char */
# .code .dl { color: #A3BE8C } /* Literal.String.Delimiter */
# .code .sd { color: #616E87 } /* Literal.String.Doc */
# .code .s2 { color: #A3BE8C } /* Literal.String.Double */
# .code .se { color: #EBCB8B } /* Literal.String.Escape */
# .code .sh { color: #A3BE8C } /* Literal.String.Heredoc */
# .code .si { color: #A3BE8C } /* Literal.String.Interpol */
# .code .sx { color: #A3BE8C } /* Literal.String.Other */
# .code .sr { color: #EBCB8B } /* Literal.String.Regex */
# .code .s1 { color: #A3BE8C } /* Literal.String.Single */
# .code .ss { color: #A3BE8C } /* Literal.String.Symbol */
# .code .bp { color: #81A1C1 } /* Name.Builtin.Pseudo */
# .code .fm { color: #88C0D0 } /* Name.Function.Magic */
# .code .vc { color: #D8DEE9 } /* Name.Variable.Class */
# .code .vg { color: #D8DEE9 } /* Name.Variable.Global */
# .code .vi { color: #D8DEE9 } /* Name.Variable.Instance */
# .code .vm { color: #D8DEE9 } /* Name.Variable.Magic */
# .code .il { color: #B48EAD } /* Literal.Number.Integer.Long */
#
# .code {
#   padding: 4px;
#   border: 1px solid grey;
#   border-radius: 4px;
#   max-width: 1000px;
#   width: 100%;
#   display: inline-block;
#   box-sizing: border-box;
#   text-align: left;
#   vertical-align: top;
#   line-height: normal;
#   overflow-x: auto;
# }
#
# .code pre {
#   white-space: pre-wrap;       /* CSS 3 */
#   white-space: -moz-pre-wrap;  /* Mozilla, since 1999 */
#   white-space: -pre-wrap;      /* Opera 4-6 */
#   white-space: -o-pre-wrap;    /* Opera 7 */
#   word-wrap: break-word;
#   overflow-wrap: break-word;
#   margin: 0;
# }
# </style>
# <div class="code"><pre><span></span><span class="n">SamplerColumn</span><span class="p">(</span>
#     <span class="n">name</span><span class="o">=</span><span class="s1">&#39;medical_expense&#39;</span><span class="p">,</span>
#     <span class="nb">type</span><span class="o">=</span><span class="s1">&#39;uniform&#39;</span><span class="p">,</span>
#     <span class="n">params</span><span class="o">=</span><span class="p">{</span>
#     <span class="s2">&quot;low&quot;</span><span class="p">:</span> <span class="mf">0.0</span><span class="p">,</span>
#     <span class="s2">&quot;high&quot;</span><span class="p">:</span> <span class="mf">20000.0</span>
# <span class="p">},</span>
#     <span class="n">conditional_params</span><span class="o">=</span><span class="p">{},</span>
#     <span class="n">convert_to</span><span class="o">=</span><span class="kc">None</span>
# <span class="p">)</span>
# </pre></div>
# 🪄 Column medical_expense updated in source DataDesigner!
# ╭─ 💬 convicted ──────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ If a peron has been convicted of a crime, 1 for true, 0 for false                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <meta charset="UTF-8">
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# .code .hll { background-color: #3B4252 }
# .code { background: #2E3440; color: #D8DEE9 }
# .code .c { color: #616E87; font-style: italic } /* Comment */
# .code .err { color: #BF616A } /* Error */
# .code .esc { color: #D8DEE9 } /* Escape */
# .code .g { color: #D8DEE9 } /* Generic */
# .code .k { color: #81A1C1; font-weight: bold } /* Keyword */
# .code .l { color: #D8DEE9 } /* Literal */
# .code .n { color: #D8DEE9 } /* Name */
# .code .o { color: #81A1C1; font-weight: bold } /* Operator */
# .code .x { color: #D8DEE9 } /* Other */
# .code .p { color: #ECEFF4 } /* Punctuation */
# .code .ch { color: #616E87; font-style: italic } /* Comment.Hashbang */
# .code .cm { color: #616E87; font-style: italic } /* Comment.Multiline */
# .code .cp { color: #5E81AC; font-style: italic } /* Comment.Preproc */
# .code .cpf { color: #616E87; font-style: italic } /* Comment.PreprocFile */
# .code .c1 { color: #616E87; font-style: italic } /* Comment.Single */
# .code .cs { color: #616E87; font-style: italic } /* Comment.Special */
# .code .gd { color: #BF616A } /* Generic.Deleted */
# .code .ge { color: #D8DEE9; font-style: italic } /* Generic.Emph */
# .code .ges { color: #D8DEE9; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .code .gr { color: #BF616A } /* Generic.Error */
# .code .gh { color: #88C0D0; font-weight: bold } /* Generic.Heading */
# .code .gi { color: #A3BE8C } /* Generic.Inserted */
# .code .go { color: #D8DEE9 } /* Generic.Output */
# .code .gp { color: #616E88; font-weight: bold } /* Generic.Prompt */
# .code .gs { color: #D8DEE9; font-weight: bold } /* Generic.Strong */
# .code .gu { color: #88C0D0; font-weight: bold } /* Generic.Subheading */
# .code .gt { color: #BF616A } /* Generic.Traceback */
# .code .kc { color: #81A1C1; font-weight: bold } /* Keyword.Constant */
# .code .kd { color: #81A1C1; font-weight: bold } /* Keyword.Declaration */
# .code .kn { color: #81A1C1; font-weight: bold } /* Keyword.Namespace */
# .code .kp { color: #81A1C1 } /* Keyword.Pseudo */
# .code .kr { color: #81A1C1; font-weight: bold } /* Keyword.Reserved */
# .code .kt { color: #81A1C1 } /* Keyword.Type */
# .code .ld { color: #D8DEE9 } /* Literal.Date */
# .code .m { color: #B48EAD } /* Literal.Number */
# .code .s { color: #A3BE8C } /* Literal.String */
# .code .na { color: #8FBCBB } /* Name.Attribute */
# .code .nb { color: #81A1C1 } /* Name.Builtin */
# .code .nc { color: #8FBCBB } /* Name.Class */
# .code .no { color: #8FBCBB } /* Name.Constant */
# .code .nd { color: #D08770 } /* Name.Decorator */
# .code .ni { color: #D08770 } /* Name.Entity */
# .code .ne { color: #BF616A } /* Name.Exception */
# .code .nf { color: #88C0D0 } /* Name.Function */
# .code .nl { color: #D8DEE9 } /* Name.Label */
# .code .nn { color: #8FBCBB } /* Name.Namespace */
# .code .nx { color: #D8DEE9 } /* Name.Other */
# .code .py { color: #D8DEE9 } /* Name.Property */
# .code .nt { color: #81A1C1 } /* Name.Tag */
# .code .nv { color: #D8DEE9 } /* Name.Variable */
# .code .ow { color: #81A1C1; font-weight: bold } /* Operator.Word */
# .code .pm { color: #ECEFF4 } /* Punctuation.Marker */
# .code .w { color: #D8DEE9 } /* Text.Whitespace */
# .code .mb { color: #B48EAD } /* Literal.Number.Bin */
# .code .mf { color: #B48EAD } /* Literal.Number.Float */
# .code .mh { color: #B48EAD } /* Literal.Number.Hex */
# .code .mi { color: #B48EAD } /* Literal.Number.Integer */
# .code .mo { color: #B48EAD } /* Literal.Number.Oct */
# .code .sa { color: #A3BE8C } /* Literal.String.Affix */
# .code .sb { color: #A3BE8C } /* Literal.String.Backtick */
# .code .sc { color: #A3BE8C } /* Literal.String.Char */
# .code .dl { color: #A3BE8C } /* Literal.String.Delimiter */
# .code .sd { color: #616E87 } /* Literal.String.Doc */
# .code .s2 { color: #A3BE8C } /* Literal.String.Double */
# .code .se { color: #EBCB8B } /* Literal.String.Escape */
# .code .sh { color: #A3BE8C } /* Literal.String.Heredoc */
# .code .si { color: #A3BE8C } /* Literal.String.Interpol */
# .code .sx { color: #A3BE8C } /* Literal.String.Other */
# .code .sr { color: #EBCB8B } /* Literal.String.Regex */
# .code .s1 { color: #A3BE8C } /* Literal.String.Single */
# .code .ss { color: #A3BE8C } /* Literal.String.Symbol */
# .code .bp { color: #81A1C1 } /* Name.Builtin.Pseudo */
# .code .fm { color: #88C0D0 } /* Name.Function.Magic */
# .code .vc { color: #D8DEE9 } /* Name.Variable.Class */
# .code .vg { color: #D8DEE9 } /* Name.Variable.Global */
# .code .vi { color: #D8DEE9 } /* Name.Variable.Instance */
# .code .vm { color: #D8DEE9 } /* Name.Variable.Magic */
# .code .il { color: #B48EAD } /* Literal.Number.Integer.Long */
#
# .code {
#   padding: 4px;
#   border: 1px solid grey;
#   border-radius: 4px;
#   max-width: 1000px;
#   width: 100%;
#   display: inline-block;
#   box-sizing: border-box;
#   text-align: left;
#   vertical-align: top;
#   line-height: normal;
#   overflow-x: auto;
# }
#
# .code pre {
#   white-space: pre-wrap;       /* CSS 3 */
#   white-space: -moz-pre-wrap;  /* Mozilla, since 1999 */
#   white-space: -pre-wrap;      /* Opera 4-6 */
#   white-space: -o-pre-wrap;    /* Opera 7 */
#   word-wrap: break-word;
#   overflow-wrap: break-word;
#   margin: 0;
# }
# </style>
# <div class="code"><pre><span></span><span class="n">SamplerColumn</span><span class="p">(</span>
#     <span class="n">name</span><span class="o">=</span><span class="s1">&#39;convicted&#39;</span><span class="p">,</span>
#     <span class="nb">type</span><span class="o">=</span><span class="s1">&#39;bernoulli&#39;</span><span class="p">,</span>
#     <span class="n">params</span><span class="o">=</span><span class="p">{</span>
#     <span class="s2">&quot;p&quot;</span><span class="p">:</span> <span class="mf">0.5</span>
# <span class="p">},</span>
#     <span class="n">conditional_params</span><span class="o">=</span><span class="p">{},</span>
#     <span class="n">convert_to</span><span class="o">=</span><span class="kc">None</span>
# <span class="p">)</span>
# </pre></div>
# 🪄 Column convicted updated in source DataDesigner!
# ╭─ 💬 homeless ───────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ If a person is homeless, 1 for true, 0 for false                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <meta charset="UTF-8">
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #D8DEE9; background-color: #242933; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #242933; background-color: #D8DEE9; padding-left: 5px; padding-right: 5px; }
# .code .hll { background-color: #3B4252 }
# .code { background: #2E3440; color: #D8DEE9 }
# .code .c { color: #616E87; font-style: italic } /* Comment */
# .code .err { color: #BF616A } /* Error */
# .code .esc { color: #D8DEE9 } /* Escape */
# .code .g { color: #D8DEE9 } /* Generic */
# .code .k { color: #81A1C1; font-weight: bold } /* Keyword */
# .code .l { color: #D8DEE9 } /* Literal */
# .code .n { color: #D8DEE9 } /* Name */
# .code .o { color: #81A1C1; font-weight: bold } /* Operator */
# .code .x { color: #D8DEE9 } /* Other */
# .code .p { color: #ECEFF4 } /* Punctuation */
# .code .ch { color: #616E87; font-style: italic } /* Comment.Hashbang */
# .code .cm { color: #616E87; font-style: italic } /* Comment.Multiline */
# .code .cp { color: #5E81AC; font-style: italic } /* Comment.Preproc */
# .code .cpf { color: #616E87; font-style: italic } /* Comment.PreprocFile */
# .code .c1 { color: #616E87; font-style: italic } /* Comment.Single */
# .code .cs { color: #616E87; font-style: italic } /* Comment.Special */
# .code .gd { color: #BF616A } /* Generic.Deleted */
# .code .ge { color: #D8DEE9; font-style: italic } /* Generic.Emph */
# .code .ges { color: #D8DEE9; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .code .gr { color: #BF616A } /* Generic.Error */
# .code .gh { color: #88C0D0; font-weight: bold } /* Generic.Heading */
# .code .gi { color: #A3BE8C } /* Generic.Inserted */
# .code .go { color: #D8DEE9 } /* Generic.Output */
# .code .gp { color: #616E88; font-weight: bold } /* Generic.Prompt */
# .code .gs { color: #D8DEE9; font-weight: bold } /* Generic.Strong */
# .code .gu { color: #88C0D0; font-weight: bold } /* Generic.Subheading */
# .code .gt { color: #BF616A } /* Generic.Traceback */
# .code .kc { color: #81A1C1; font-weight: bold } /* Keyword.Constant */
# .code .kd { color: #81A1C1; font-weight: bold } /* Keyword.Declaration */
# .code .kn { color: #81A1C1; font-weight: bold } /* Keyword.Namespace */
# .code .kp { color: #81A1C1 } /* Keyword.Pseudo */
# .code .kr { color: #81A1C1; font-weight: bold } /* Keyword.Reserved */
# .code .kt { color: #81A1C1 } /* Keyword.Type */
# .code .ld { color: #D8DEE9 } /* Literal.Date */
# .code .m { color: #B48EAD } /* Literal.Number */
# .code .s { color: #A3BE8C } /* Literal.String */
# .code .na { color: #8FBCBB } /* Name.Attribute */
# .code .nb { color: #81A1C1 } /* Name.Builtin */
# .code .nc { color: #8FBCBB } /* Name.Class */
# .code .no { color: #8FBCBB } /* Name.Constant */
# .code .nd { color: #D08770 } /* Name.Decorator */
# .code .ni { color: #D08770 } /* Name.Entity */
# .code .ne { color: #BF616A } /* Name.Exception */
# .code .nf { color: #88C0D0 } /* Name.Function */
# .code .nl { color: #D8DEE9 } /* Name.Label */
# .code .nn { color: #8FBCBB } /* Name.Namespace */
# .code .nx { color: #D8DEE9 } /* Name.Other */
# .code .py { color: #D8DEE9 } /* Name.Property */
# .code .nt { color: #81A1C1 } /* Name.Tag */
# .code .nv { color: #D8DEE9 } /* Name.Variable */
# .code .ow { color: #81A1C1; font-weight: bold } /* Operator.Word */
# .code .pm { color: #ECEFF4 } /* Punctuation.Marker */
# .code .w { color: #D8DEE9 } /* Text.Whitespace */
# .code .mb { color: #B48EAD } /* Literal.Number.Bin */
# .code .mf { color: #B48EAD } /* Literal.Number.Float */
# .code .mh { color: #B48EAD } /* Literal.Number.Hex */
# .code .mi { color: #B48EAD } /* Literal.Number.Integer */
# .code .mo { color: #B48EAD } /* Literal.Number.Oct */
# .code .sa { color: #A3BE8C } /* Literal.String.Affix */
# .code .sb { color: #A3BE8C } /* Literal.String.Backtick */
# .code .sc { color: #A3BE8C } /* Literal.String.Char */
# .code .dl { color: #A3BE8C } /* Literal.String.Delimiter */
# .code .sd { color: #616E87 } /* Literal.String.Doc */
# .code .s2 { color: #A3BE8C } /* Literal.String.Double */
# .code .se { color: #EBCB8B } /* Literal.String.Escape */
# .code .sh { color: #A3BE8C } /* Literal.String.Heredoc */
# .code .si { color: #A3BE8C } /* Literal.String.Interpol */
# .code .sx { color: #A3BE8C } /* Literal.String.Other */
# .code .sr { color: #EBCB8B } /* Literal.String.Regex */
# .code .s1 { color: #A3BE8C } /* Literal.String.Single */
# .code .ss { color: #A3BE8C } /* Literal.String.Symbol */
# .code .bp { color: #81A1C1 } /* Name.Builtin.Pseudo */
# .code .fm { color: #88C0D0 } /* Name.Function.Magic */
# .code .vc { color: #D8DEE9 } /* Name.Variable.Class */
# .code .vg { color: #D8DEE9 } /* Name.Variable.Global */
# .code .vi { color: #D8DEE9 } /* Name.Variable.Instance */
# .code .vm { color: #D8DEE9 } /* Name.Variable.Magic */
# .code .il { color: #B48EAD } /* Literal.Number.Integer.Long */
#
# .code {
#   padding: 4px;
#   border: 1px solid grey;
#   border-radius: 4px;
#   max-width: 1000px;
#   width: 100%;
#   display: inline-block;
#   box-sizing: border-box;
#   text-align: left;
#   vertical-align: top;
#   line-height: normal;
#   overflow-x: auto;
# }
#
# .code pre {
#   white-space: pre-wrap;       /* CSS 3 */
#   white-space: -moz-pre-wrap;  /* Mozilla, since 1999 */
#   white-space: -pre-wrap;      /* Opera 4-6 */
#   white-space: -o-pre-wrap;    /* Opera 7 */
#   word-wrap: break-word;
#   overflow-wrap: break-word;
#   margin: 0;
# }
# </style>
# <div class="code"><pre><span></span><span class="n">SamplerColumn</span><span class="p">(</span>
#     <span class="n">name</span><span class="o">=</span><span class="s1">&#39;homeless&#39;</span><span class="p">,</span>
#     <span class="nb">type</span><span class="o">=</span><span class="s1">&#39;bernoulli&#39;</span><span class="p">,</span>
#     <span class="n">params</span><span class="o">=</span><span class="p">{</span>
#     <span class="s2">&quot;p&quot;</span><span class="p">:</span> <span class="mf">0.5</span>
# <span class="p">},</span>
#     <span class="n">conditional_params</span><span class="o">=</span><span class="p">{},</span>
#     <span class="n">convert_to</span><span class="o">=</span><span class="kc">None</span>
# <span class="p">)</span>
# </pre></div>
# 🪄 Column homeless updated in source DataDesigner!
# DataDesigner(
#     model_suite: apache-2.0
#     sampler_columns: [
#         "income",
#         "family_size",
#         "medical_expense",
#         "convicted",
#         "homeless"
#     ]
# )

# %%
preview_output = designer.preview()
preview_output.display_sample_record()
# Out:
# [13:44:17] [INFO] 🚀 Generating preview
# [13:44:19] [INFO] 🎲 Step 1: Using samplers to generate 5 columns
# [13:44:19] [INFO] 🎉 Your dataset preview is ready!
#
#                                                  Generated Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name                                               ┃ Value                                                      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ income                                             │ 41738.73665811641                                          │
# ├────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ family_size                                        │ 1.7548758628949077                                         │
# ├────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ medical_expense                                    │ 11476.53091193456                                          │
# ├────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ convicted                                          │ 1.0                                                        │
# ├────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ homeless                                           │ 1.0                                                        │
# └────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────┘
#
#                                                     [index: 0]

# %%
designer.with_evaluation_report()
# Out:
# DataDesigner(
#     model_suite: apache-2.0
#     sampler_columns: [
#         "income",
#         "family_size",
#         "medical_expense",
#         "convicted",
#         "homeless"
#     ]
# )

# %%
workflow_run = designer.create(num_records=100, name="Visionary Model Dataset")
# Out:
# [13:46:46] [INFO] 🚀 Submitting batch workflow
# ▶️ Creating Workflow: w_33aKBdSF9NSHaBFk258vADAnVU4
# ▶️ Created Workflow Run: wr_33aKBiLQJmjUj2Blg1E6L4xNNKe
# 🔗 Workflow Run console link: https://console.gretel.ai/workflows/w_33aKBdSF9NSHaBFk258vADAnVU4/runs/wr_33aKBiLQJmjUj2Blg1E6L4xNNKe
